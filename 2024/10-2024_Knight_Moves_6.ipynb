# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import time
import seaborn as sns
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import random
from itertools import permutations
from matplotlib.colors import ListedColormap, BoundaryNorm
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display,Image,HTML

# %% [markdown]
# # Knight moves 6

# %%
# Define the grid layout
grid = [
    ['A', 'B', 'B', 'C', 'C', 'C'],
    ['A', 'B', 'B', 'C', 'C', 'C'],
    ['A', 'A', 'B', 'B', 'C', 'C'],
    ['A', 'A', 'B', 'B', 'C', 'C'],
    ['A', 'A', 'A', 'B', 'B', 'C'],
    ['A', 'A', 'A', 'B', 'B', 'C']
]

chess_grid = [
    ['a6', 'b6', 'c6', 'd6', 'e6', 'f6'],
    ['a5', 'b5', 'c5', 'd5', 'e5', 'f5'],
    ['a4', 'b4', 'c4', 'd4', 'e4', 'f4'],
    ['a3', 'b3', 'c3', 'd3', 'e3', 'f3'],
    ['a2', 'b2', 'c2', 'd2', 'e2', 'f2'],
    ['a1', 'b1', 'c1', 'd1', 'e1', 'f1']
]

# Map grid coordinates to values for easier referencing
rows = [1, 2, 3, 4, 5, 6]
columns = ['a', 'b', 'c', 'd', 'e', 'f']

def get_knight_moves(position,N=6):
    i,j = position
    moves=[(2, 1), (1, 2), (-1, 2), (-2, 1), (-2, -1), (-1, -2), (1, -2), (2, -1)]
    return [(x+i,y+j) for x,y in moves if x+i >=0 and x+i<N and y+j>=0 and y+j<N ]

# Recursive function to find all valid paths
def find_paths(start, end, path=None, max_steps=10):
    if path is None:
        path = [start]  # Initialize the path with the start position
    if start == end:
        return [path]
    if len(path) >= max_steps:
        return []
    
    valid_paths = []
    for move in get_knight_moves(start):
        if move not in path:  # Avoid revisiting squares
            new_path = path + [move]
            valid_paths += find_paths(move, end, new_path, max_steps)
    return valid_paths

# Function to compute score for a single path
def compute_score(path, values, grid):
    score = values['A']  # Start with A points
    for i in range(1, len(path)):
        prev_cell = path[i-1]
        current_cell = path[i]
        prev_value = grid[prev_cell[0]][prev_cell[1]]
        current_value = grid[current_cell[0]][current_cell[1]]

        if prev_value != current_value:
            score *= values[current_value]
        else:
            score += values[current_value]
    return score

# %%
# Define all possible distinct values for A, B, C
possible_values = [i for i in range(1, 50)]

# Find paths and check scores
def solve_puzzle(grid):
    i = 0
    Min_comb_abc = [50]
    Comb = {}
    Integers = {}
    Paths = {}
    valid_combinations = [(A, B, C) for A, B, C in permutations(range(1, 50), 3) if A + B + C < 50]
    for A, B, C in valid_combinations:

        if (A + B + C) < min(Min_comb_abc):
            values = {'A': A, 'B': B, 'C': C}

            # Find paths from a1 to f6 and a6 to f1
            path1 = find_paths((0, 0), (5, 5))  # a1 to f6
            path2 = find_paths((5, 0), (0, 5))  # a6 to f1

            # Check if any path scores exactly 2024 points
            for p1 in path1:
                score1 = compute_score(p1, values,grid)
                if score1 == 2024:
                    for p2 in path2:
                        score2 = compute_score(p2, values,grid)
                        if score2 == 2024 and A + B + C < 50:

                            Min_comb_abc.append(A+B+C)

                            Integers["A"] = A
                            Integers["B"] = B
                            Integers["C"] = C

                            Paths["p1"] = p1
                            Paths["p2"] = p2

                            Comb[f"Integers {i}"] = Integers
                            Comb[f"Paths {i}"] = Paths
                            Comb[f"Sum {i}"] = A + B + C

                            #print(f"Solution: A={A}, B={B}, C={C}")
                            #print(f"Path 1: {p1}, Path 2: {p2}")
                            #return Integers, Paths
    return Comb

start_time = time.time()
Final_sol = solve_puzzle(grid=grid)
end_time = time.time()

# %%
execution_time = end_time - start_time
minutes, seconds = divmod(execution_time, 60)

Integers = Final_sol["Integers 0"]
A = Integers["A"]
B = Integers["B"]
C = Integers["C"]

Paths = Final_sol["Paths 0"]
path1 = Paths["p1"]
path2 = Paths["p2"]

knight_path1 = ""
knight_path2 = ""

for x,y in path1:
    knight_path1 += f"{chess_grid[x][y]} -> "

if knight_path1.endswith(" -> "):
    knight_path1 = knight_path1[:-4]

for x,y in path2:
    knight_path2 += f"{chess_grid[x][y]} -> "

if knight_path2.endswith(" -> "):
    knight_path2 = knight_path2[:-4]


print(f"Solution: A={A}, B={B}, C={C}, and A + B + C = {A+B+C}")
print(f"Path 1: {knight_path1} \nPath 2: {knight_path2}")
print(f"Execution time: {int(minutes)} minutes {seconds:.2f} seconds")
# Out:
# Solution: A=2, B=5, C=4, and A + B + C = 11
# Path 1: a6 -> b4 -> c6 -> d4 -> f3 -> d2 -> c4 -> e3 -> f1
# Path 2: a1 -> b3 -> c5 -> d3 -> e5 -> c4 -> b6 -> d5 -> f6
# Execution time: 1 minutes 43.25 seconds

# %% [markdown]
# # Visualizing the paths

# %%
# Custom colors for the heatmap


def output(Paths,grid):

    path_grid1 = np.zeros((6,6))
    path_grid2 = np.zeros((6,6))

    path1 = Paths["p1"]
    path2 = Paths["p2"]

    for square in path1:
        path_grid1[square] += 1

    for square in path2:
        path_grid2[square] -= 1

    colors = ['white', 'red', 'blue', 'purple']
    cmap = ListedColormap(colors)
    norm = BoundaryNorm([0, 1, 2, 3, 4], cmap.N)

    # Define x and y labels
    x_labels = ['a', 'b', 'c', 'd', 'e', 'f']
    y_labels = ['1', '2', '3', '4', '5', '6']

    # Convert grid to string array
    x = np.array(grid).astype(str)
    x[x == '0'] = '-'  # Assuming you meant to replace zeros with '-'

    # Create a figure with two subplots
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))

    # Plot the first heatmap
    sns.heatmap(path_grid1, annot=x, cbar=False, cmap='PiYG', fmt='', center=0, 
                linewidths=1, linecolor='k', annot_kws={'size': 12, 'color': 'k'}, 
                alpha=.4, ax=axs[0])
    #axs[0].axis('off')  # Hide the axis
    axs[0].set_xticks(np.arange(len(x_labels)) + 0.5)
    axs[0].set_yticks(np.arange(len(y_labels)) + 0.5)
    axs[0].set_xticklabels(x_labels, fontweight='bold', fontsize=12)
    axs[0].set_yticklabels(y_labels, fontweight='bold', fontsize=12)
    axs[0].tick_params(axis='both', which='both', length=0)  # Hide tick marks
    axs[0].set_title(f'Path from a1 to f6 \n{knight_path1}', fontsize=14, fontweight='bold')  # Add subtitle

    # Plot the second heatmap
    sns.heatmap(path_grid2, annot=x, cbar=False, cmap='PiYG', fmt='', center=0, 
                linewidths=1, linecolor='k', annot_kws={'size': 12, 'color': 'k'}, 
                alpha=.4, ax=axs[1])
    #axs[1].axis('off')  # Hide the axis
    axs[1].set_xticks(np.arange(len(x_labels)) + 0.5)
    axs[1].set_yticks(np.arange(len(y_labels)) + 0.5)
    axs[1].set_xticklabels(x_labels, fontweight='bold', fontsize=12)
    axs[1].set_yticklabels(y_labels, fontweight='bold', fontsize=12)
    axs[1].tick_params(axis='both', which='both', length=0)  # Hide tick marks
    axs[1].set_title(f'Path from a6 to f1 \n{knight_path2} ', fontsize=14, fontweight='bold')  # Add subtitle

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Adjust space between subplots
    plt.subplots_adjust(wspace=0.1)  # Increase the width space between the subplots

    # Show the plot
    plt.show()

output(Paths,np.array(grid))
